# %%
import pandas as pd # importing  pandas
df=pd.read_csv("/content/pandas1.csv") # reading a csv file by reading the path for excel df pd.read_excel("path","sheetname")
df #df[:] to print everything
# Out:
#          date  temperature  windspeed  event
# 0  01-01-2017           35          6   rain
# 1  02-01-2017           36          7  sunny
# 2  03-01-2017           35          4  sunny
# 3  04-01-2017           37          3   rain
# 4  05-01-2017           35          7   snow
# 5  06-01-2017           32          6   snow

# %%
row , column= df.shape #shape is for dimension
row
# Out:
# 4

# %%
df.head() # prints inital entry
# Out:
#          date  temperature  windspeed  event
# 0  01-01-2017           35          6   rain
# 1  02-01-2017           36          7  sunny
# 2  03-01-2017           35          4  sunny
# 3  04-01-2017           37          3   rain
# 4  05-01-2017           35          7   snow

# %%
df.head(3)
# Out:
#          date  temperature  windspeed  event
# 0  01-01-2017           35          6   rain
# 1  02-01-2017           36          7  sunny
# 2  03-01-2017           35          4  sunny

# %%
df.tail(1) #to last entry
# Out:
#          date  temperature  windspeed event
# 5  06-01-2017           32          6  snow

# %%
df[2:5] # to print middle entry
# Out:
#          date  temperature  windspeed  event
# 2  03-01-2017           35          4  sunny
# 3  04-01-2017           37          3   rain
# 4  05-01-2017           35          7   snow

# %%
df.columns
# Out:
# Index(['date', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.event #to print content inside each column or df['event] if using dictionary
# Out:
# 0     rain
# 1    sunny
# 2    sunny
# 3     rain
# 4     snow
# 5     snow
# Name: event, dtype: object

# %%
df[['event','date']]
# Out:
#    event        date
# 0   rain  01-01-2017
# 1  sunny  02-01-2017
# 2  sunny  03-01-2017
# 3   rain  04-01-2017
# 4   snow  05-01-2017
# 5   snow  06-01-2017

# %%
df.temperature.max() # min ,average-mean,std-standard deviation
# Out:
# 37

# %%
df.describe() #provide statistical data
# Out:
#        temperature  windspeed
# count      6.00000   6.000000
# mean      35.00000   5.500000
# std        1.67332   1.643168
# min       32.00000   3.000000
# 25%       35.00000   4.500000
# 50%       35.00000   6.000000
# 75%       35.75000   6.750000
# max       37.00000   7.000000

# %%
df[['date','temperature']][df.temperature==df['temperature'].max()]
# Out:
#          date  temperature
# 3  04-01-2017           37

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.set_index('date', inplace=True)

# %%
df
# Out:
#             temperature  windspeed  event
# date
# 01-01-2017           35          6   rain
# 02-01-2017           36          7  sunny
# 03-01-2017           35          4  sunny
# 04-01-2017           37          3   rain
# 05-01-2017           35          7   snow
# 06-01-2017           32          6   snow

# %%
df.loc['01-01-2017']
# Out:
# temperature      35
# windspeed         6
# event          rain
# Name: 01-01-2017, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#          date  temperature  windspeed  event
# 0  01-01-2017           35          6   rain
# 1  02-01-2017           36          7  sunny
# 2  03-01-2017           35          4  sunny
# 3  04-01-2017           37          3   rain
# 4  05-01-2017           35          7   snow
# 5  06-01-2017           32          6   snow

# %%
dataset={
    'date':['1/1/17','1/2/17','1/3/17'],
    'temperature':[32,35,28],
    'windspeed':[6,7,2],
    'event':['rain','Sunny','Snow']
}
df=pd.DataFrame(dataset)
df
# Out:
#      date  temperature  windspeed  event
# 0  1/1/17           32          6   rain
# 1  1/2/17           35          7  Sunny
# 2  1/3/17           28          2   Snow
