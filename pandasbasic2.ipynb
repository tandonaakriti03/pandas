# %%
import pandas as pd
df=pd.read_csv("/content/stock_data.csv")
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
#if you dont have header
#import pandas as pd
#df=pd.read_csv("/content/stock_data.csv",header=None,names=["ticketr","eps","revenue","price","people"])
#df
# Out:
#      ticketr            eps  revenue  price         people
# 0  stockdata            NaN      NaN    NaN            NaN
# 1    tickers            eps  revenue  price         people
# 2      GOOGL          27.82       87    845     larry page
# 3        WMT           4.61      484     65           n.a.
# 4       MSFT             -1       85     64     bill gates
# 5       RIL   not available       50   1023  mukesh ambani
# 6       TATA            5.6       -1   n.a.     ratan tata

# %%
#read limited data
import pandas as pd
df=pd.read_csv("/content/stock_data.csv",nrows=1)
df
# Out:
#   stockdata Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0   tickers        eps    revenue      price     people

# %%
#clean messy data from file like "n.a." or 'not available' with nan
import pandas as pd
df=pd.read_csv("/content/stock_data.csv",na_values={
    'eps' : ["not available","n.a."],
    'revenue' : ["not available","n.a.",-1],
    'people' : ["not available","n.a."],
    'price':["not available","n.a."]
})
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
#to move
df.to_csv('new.csv',index=False) #to remove the index

# %%
df.columns
# Out:
# Index(['tickers', 'eps', 'revenue', 'price', 'people'], dtype='object')

# %%
df.to_csv("new.csv",columns=['tickers','eps']) #exporting few columns to csv

# %%
import pandas as pd
def convert_people_cell(cell):
  if cell=="n.a.":
    return 'sam walton'
  return cell
df=pd.read_excel("/content/stock_data.xlsx",converters={
    'people': convert_people_cell
})
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65     sam walton
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata
